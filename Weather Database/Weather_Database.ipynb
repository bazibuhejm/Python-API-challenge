# %%
#!pip install pandas

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the NumPy module.
import numpy as np
# Import timeit.
import timeit
import random
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#!pip install citipy

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 789

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "London"
api_key= "fc8ee2020d0333a1f22fc17ef574ce08"
# Build query URL
query_url = url + "appid=" + api_key + "&q=" + city

# %%
# Get weather data
weather_response = requests.get(query_url)
weather_json = weather_response.json()

# Get the temperature from the response
display (weather_json)
# Out:
# {'coord': {'lon': -0.1257, 'lat': 51.5085},
#  'weather': [{'id': 721,
#    'main': 'Haze',
#    'description': 'haze',
#    'icon': '50n'}],
#  'base': 'stations',
#  'main': {'temp': 290.57,
#   'feels_like': 290.8,
#   'temp_min': 287.14,
#   'temp_max': 293.15,
#   'pressure': 1021,
#   'humidity': 93},
#  'visibility': 5000,
#  'wind': {'speed': 1.54, 'deg': 60},
#  'clouds': {'all': 2},
#  'dt': 1626835989,
#  'sys': {'type': 2,
#   'id': 2006068,
#   'country': 'GB',
#   'sunrise': 1626840510,
#   'sunset': 1626897898},
#  'timezone': 3600,
#  'id': 2643743,
#  'name': 'London',
#  'cod': 200}

# %%
temperatures=[]
counter= 0
# api_key= "fc8ee2020d0333a1f22fc17ef574ce08"
# # loop throught the list of units and append them to temperatures list
# for city in cities:
#     # Build query URL based on current element in units
#     query_url = url + "appid=" + api_key + "&q=" + city

#     # Get weather data
#     try:
#         weather_response = requests.get(query_url)
#         weather_json = weather_response.json()
    
#         Weather_Data= {
# #             "City":weather_json["name"],
#             "Country":weather_json["sys"]["country"],
#             "lat":weather_json["coord"]["lat"],
#             "Lng":weather_json["coord"]["lon"],
#             "Max Temp":weather_json["main"]["temp_max"],
#             "Humidity":weather_json["main"]["humidity"],
#             "Cloudiness":weather_json["clouds"]["all"],
#             "Wind speed":weather_json["wind"]["speed"],
#             "Current Description":weather_json["weather"]["description"]
#         }
#         temperatures.append(Weather_Data)
#         counter= counter+1
#     except:   
#          print("not found")
        
# temperatures

# %%
#set up list to hold response info
city_weather = []
counter = 0
url = "http://api.openweathermap.org/data/2.5/weather?"
api_key= "fc8ee2020d0333a1f22fc17ef574ce08"
units="imperial"
query_url = f"{url}appid={api_key}&units={units}&q="
#loop thrugh the list of cities and perform a request for weather data for each city
for city in cities:
    # Build partial query URL

    #gets response for each city
    response = requests.get(query_url + city).json()
    #try/except statement to handle errors when city is not found on openweather site
    try:
        
        #create dictionary
        weather_data = {
            "City": response['name'],
            "Lat": response['coord']['lat'],
            "Lng": response['coord']['lon'],
            "Max Temp": response['main']['temp_max'],
            "Humidity": response['main']['humidity'],
            "Cloudiness": response['clouds']['all'],
            "Wind Speed": response['wind']['speed'],
            "Country": response['sys']['country'],
            "Current Description":response["weather"][0]["description"],
            "Date": response['dt']
        }
        city_weather.append(weather_data)
        counter = counter + 1
    except:
        print ("city not found "+ city)
# Out:
# city not found alianca
# city not found tarudant
# city not found taolanaro
# city not found marcona
# city not found amderma
# city not found bolungarvik
# city not found illoqqortoormiut
# city not found wulanhaote
# city not found barentsburg
# city not found labutta
# city not found lolua
# city not found vaitupu
# city not found mys shmidta
# city not found khonuu
# city not found ijaki
# city not found attawapiskat
# city not found nizhneyansk
# city not found taburi
# city not found ciras
# city not found grand river south east
# city not found bocaranga
# city not found kuche
# city not found mme
# city not found halalo
# city not found ngukurr
# city not found belushya guba
# city not found tsihombe
# city not found maghama
# city not found umzimvubu
# city not found qibili
# city not found raozan
# city not found bargal
# city not found karakose
# city not found saleaula
# city not found samalaeulu
# city not found tumannyy
# city not found karistos
# ...

# %%
city_weather
# Out:
# [{'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 40.84,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'SJ',
#   'Current Description': 'broken clouds',
#   'Date': 1626836392},
#  {'City': 'Kyabé',
#   'Lat': 9.4515,
#   'Lng': 18.9449,
#   'Max Temp': 71.38,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.94,
#   'Country': 'TD',
#   'Current Description': 'light rain',
#   'Date': 1626836633},
#  {'City': 'Yabēlo',
#   'Lat': 4.8833,
#   'Lng': 38.0833,
#   'Max Temp': 56.7,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 10.69,
#   'Country': 'ET',
#   'Current Description': 'light rain',
#   'Date': 1626836633},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 71.85,
#   'Humidity': 60,
#   'Cloudiness': 72,
#   'Wind Speed': 22.57,
#   'Country': 'PF',
#   'Current Description': 'broken clouds',
#   'Date': 1626836634},
#  {'City': 'East London',
# ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_weather)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Longyearbyen  78.2186   15.6401     40.84        81          75
# 1         Kyabé   9.4515   18.9449     71.38        93         100
# 2        Yabēlo   4.8833   38.0833     56.70        79         100
# 3       Rikitea -23.1203 -134.9692     71.85        60          72
# 4   East London -33.0153   27.9116     54.79        68          99
# 5  Kruisfontein -34.0033   24.7314     45.88        71          77
# 6      Penzance  50.1186   -5.5371     70.81        87           3
# 7     Hithadhoo  -0.6000   73.0833     81.73        77         100
# 8     Boa Vista   2.8197  -60.6733     76.98        88          75
# 9     Caravelas -17.7125  -39.2481     71.29        66         100
#
#    Wind Speed Country   Current Description        Date
# 0        3.44      SJ         broken clouds  1626836392
# 1        3.94      TD            light rain  1626836633
# 2       10.69      ET            light rain  1626836633
# ...

# %%
#city_data_df.to_csv("city_data_df.csv")

# %%
len(city_data_df)
# Out:
# 727

# %%
len(city_weather)
# Out:
# 727
